# %% [markdown]
# <a href="https://colab.research.google.com/github/Aynahd/Freshman/blob/main/Airplanes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /archive.zip
# Out:
# Archive:  /archive.zip
#   inflating: Airplanes_Annotations/Airplanes_Annotations/42845.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/428451.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/428452.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/428461.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/428462.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/42847.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/428472.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/42848.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/428481.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/428482.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/428483.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/42849.csv
#   inflating: Airplanes_Annotations/Airplanes_Annotations/428491.csv
# ...

# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import cv2
import os

# %%
csv_data = pd.read_csv('archive.csv')
image_folder = 'images'
image_files = os.listdir(image_folder)
image_data = []
for file in image_files:
    img = cv2.imread(os.path.join(image_folder, file))
    # Assuming you want to resize the images to a specific size
    img = cv2.resize(img, (width, height))
    image_data.append(img)

# Split data into train and test sets
X_train_img, X_test_img, y_train, y_test = train_test_split(image_data, csv_data['labels'], test_size=0.2, random_state=42)
X_train_csv, X_test_csv, y_train, y_test = train_test_split(csv_data.drop('labels', axis=1), csv_data['labels'], test_size=0.2, random_state=42)

# Optionally, convert image data to numpy arrays for compatibility with machine learning models
import numpy as np
X_train_img = np.array(X_train_img)
X_test_img = np.array(X_test_img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-705f4e1a3aac> in <cell line: 1>()
# ----> 1 csv_data = pd.read_csv('archive.csv')
#       2 image_folder = 'images'
#       3 image_files = os.listdir(image_folder)
#       4 image_data = []
#       5 for file in image_files:
#
# ...

# %%
img = cv2.imread('Images/Images/airplane_186.jpg')
import matplotlib.pyplot as plt
plt.imshow(img)
plt.axis('off')
plt.show()
