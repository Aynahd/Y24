# %% [markdown]
# <a href="https://colab.research.google.com/github/Aynahd/Freshman/blob/main/RCNN_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'airplanes-dataset-for-rcnn:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F985493%2F1664328%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240420%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240420T130723Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading airplanes-dataset-for-rcnn, 12895593 bytes compressed
# [==================================================] 12895593 bytes downloaded
# Downloaded and uncompressed: airplanes-dataset-for-rcnn
# Data source import complete.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_109.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_271.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_184.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_429.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_257.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_628.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/428452.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_005.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_290.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_177.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_643.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_611.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_363.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_487.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_288.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_663.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_548.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_023.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_293.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_249.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_631.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_214.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_662.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_362.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_700.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_358.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_284.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_361.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_138.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_248.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_406.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_376.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_555.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_461.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_011.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_508.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_216.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_387.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_231.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_058.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_221.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_009.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_126.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_627.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_517.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_202.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_078.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_179.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_097.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_052.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_055.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_661.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_381.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_432.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_159.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_572.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_493.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_263.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_511.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_561.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_564.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_149.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_267.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_404.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_577.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_200.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_207.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_565.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_085.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_601.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_015.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_490.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_050.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_428.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_240.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_049.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_076.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_480.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_046.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_213.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_507.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_581.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/hotanairport2-rgb.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_201.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_402.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_618.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_260.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_215.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_592.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_550.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_369.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_042.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_534.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/hotanairport5.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_348.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_638.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_414.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_690.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_287.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_081.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_229.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_037.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_625.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/428482.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_344.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_127.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_151.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_633.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_282.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_230.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_519.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_304.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_242.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_501.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane_669.csv
# /kaggle/input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations/airplane
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_304.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_566.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_292.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_066.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_131.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_162.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_692.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_389.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_565.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_221.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_008.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_078.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_648.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_265.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_194.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_544.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_242.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/428481.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_627.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_225.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_492.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_185.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_168.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_065.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_379.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_208.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_039.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_524.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_510.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_230.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_501.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_385.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_327.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_357.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_664.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_328.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_509.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_689.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_212.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_657.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_588.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_614.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_070.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_668.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_421.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_469.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_531.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_160.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_546.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_007.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_025.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_086.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/hotanairport1-rgb.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_373.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_615.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_508.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_563.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_676.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_521.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_239.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_561.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/428492.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/hotanairport5-rgb.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_197.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_224.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_609.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_247.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_411.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_578.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_280.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_174.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_483.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/Planes6.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_486.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_400.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_014.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_180.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_091.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_334.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_650.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_533.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_154.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_349.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_326.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_144.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_365.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_522.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_011.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_376.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_382.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_598.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_264.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_410.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_211.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_217.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_586.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_587.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_139.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_543.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_666.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_412.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_413.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_068.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_047.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_018.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/428483.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_251.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_374.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_249.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_354.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_454.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_094.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_096.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_497.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_183.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_418.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_115.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_643.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_575.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_262.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/Planes8.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_276.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/Planes10.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_063.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_222.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_111.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_449.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_548.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_608.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_112.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_395.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_696.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_362.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_582.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_347.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_320.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_356.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_132.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_044.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_335.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_229.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_569.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_361.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_550.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_371.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_661.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_446.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_236.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_369.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_275.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_511.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_067.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_076.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_485.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_170.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_455.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_415.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_675.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_447.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/hotanairport5.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_470.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_337.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_644.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_256.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_329.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/Planes4.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_061.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_438.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_502.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_306.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_145.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_252.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_480.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_600.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_481.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_381.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_172.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_163.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_192.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_273.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_171.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_555.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_435.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_093.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_201.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_539.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_529.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_417.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_406.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_041.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_402.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_072.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_669.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_310.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_658.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_695.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_191.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_186.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_261.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_331.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_616.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_512.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_393.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_028.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_442.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_368.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_004.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_536.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_397.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_146.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_215.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_117.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/428482.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_098.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_006.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_173.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_517.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_428.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_551.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_182.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_138.jpg
# /kaggle/input/airplanes-dataset-for-rcnn/Images/Images/airplane_240.jpg

# %%
# !pip uninstall opencv-python -y
# !pip uninstall opencv-contrib-python -y
# !pip uninstall opencv-python-headless -y
# !pip uninstall opencv-contrib-python-headless -y
# !pip uninstall opencv-contrib-python opencv-python
# !pip install opencv-contrib-python
# Out:
# Found existing installation: opencv-python 4.8.0.76
# Uninstalling opencv-python-4.8.0.76:
#   Successfully uninstalled opencv-python-4.8.0.76
# Found existing installation: opencv-contrib-python 4.8.0.76
# Uninstalling opencv-contrib-python-4.8.0.76:
#   Successfully uninstalled opencv-contrib-python-4.8.0.76
# Found existing installation: opencv-python-headless 4.9.0.80
# Uninstalling opencv-python-headless-4.9.0.80:
#   Successfully uninstalled opencv-python-headless-4.9.0.80
# WARNING: Skipping opencv-contrib-python-headless as it is not installed.
# WARNING: Skipping opencv-contrib-python as it is not installed.
# WARNING: Skipping opencv-python as it is not installed.
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 MB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-contrib-python) (1.25.2)

# %%
import tensorflow_datasets as tfds
import os,cv2,keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
#from tqdm.notebook import tqdm
from tqdm import tqdm
import time
import random

from keras.layers import Dense
from keras import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.applications.vgg16 import VGG16

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']

    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])

    if x_right < x_left or y_bottom < y_top:
        return 0.0
    intersection_area = (x_right - x_left) * (y_bottom - y_top)
    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])
    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
def get_rectangle(csv_annot):
    df = pd.read_csv(csv_annot)
    boxes=[]
    for row in df.iterrows():
        x1 = int(row[1][0].split(" ")[0])
        y1 = int(row[1][0].split(" ")[1])
        x2 = int(row[1][0].split(" ")[2])
        y2 = int(row[1][0].split(" ")[3])
        box={"x1":x1,"x2":x2,"y1":y1,"y2":y2}
        boxes.append(box)
    return boxes

# %%
def rectang_from_image(image,x,y,w,h):
    timage = image[y:y+h,x:x+w]
    resized = cv2.resize(timage,
                     (224,224),
                     interpolation = cv2.INTER_AREA)
    return resized

# %%
max_proposal = 2000
max_samples = 30
IOU_treshold_plane = 0.7
IOU_treshold_background = 0.3

dataset_path = "../input/airplanes-dataset-for-rcnn/Images/Images"
annot="../input/airplanes-dataset-for-rcnn/Airplanes_Annotations/Airplanes_Annotations"

ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

train_images=[]
train_labels=[]
images=os.listdir(dataset_path)

# %%
img_name=random.choice(images)
img = cv2.imread(os.path.join(dataset_path,img_name))
plt.imshow(img)
csv_file = os.path.join(annot,str(img_name).split(".")[0]+".csv")
boxes=get_rectangle(csv_file)
for box in boxes:
    cv2.rectangle(img,(box['x1'],box['y1']),(box['x2'],box['y2']),(255,0,0), 2)
plt.figure()
plt.imshow(img)

cv2.setUseOptimized(True);
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
ss.setBaseImage(img)
ss.switchToSelectiveSearchFast()
rects = ss.process()
imOut = img.copy()
for i, rect in (enumerate(rects)):
    x, y, w, h = rect
    cv2.rectangle(imOut, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
# plt.figure()
plt.imshow(imOut)

# %%
for file in tqdm(images[:100], desc="creating dataset"):
    try:
        box_values=[]
        image=cv2.imread(os.path.join(dataset_path,file))
        csv_path = os.path.join(annot,file.split(".")[0]+".csv")
        box_values.extend(get_rectangle(csv_path))
        ss.setBaseImage(image)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process()
        imout = image.copy()
        counter=flag=falsecounter=fflag=bflag = 0
        for e, result in  enumerate(ssresults):
            if e< max_proposal and flag==0:
                for a_box in box_values:
                    x,y,w,h = result
                    iou = get_iou(a_box,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                    if counter < max_samples:
                        if iou > IOU_treshold_plane:
                            train_images.append(rectang_from_image(image,x,y,w,h))
                            train_labels.append(1)
                            counter +=1
                    else:
                        fflag = 1
                    if falsecounter < max_samples:
                        if iou < IOU_treshold_background:
                            train_images.append(rectang_from_image(image,x,y,w,h))
                            train_labels.append(0)
                            falsecounter += 1
                    else:
                        bflag = 1
                if fflag == 1 and bflag==1:
                    flag=1
    except Exception as e:
        print(e)
        continue

# %%
vggmodel = VGG16(weights='imagenet', include_top=True)

for layers in (vggmodel.layers)[:15]:
    print(layers)
    layers.trainable = False

X= vggmodel.layers[-2].output
predictions = Dense(1, activation="sigmoid")(X)
model_final = Model(vggmodel.input,predictions)
opt = Adam(lr=0.0001)
model_final.compile(loss = keras.losses.binary_crossentropy, optimizer = opt, metrics=["accuracy"])
model_final.summary()

# %%
X_new = np.array(train_images)
y_new = np.array(train_labels)

X_train, X_test , y_train, y_test = train_test_split(X_new,y_new,test_size=0.10)

trdata    = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=0)
traindata = trdata.flow(x=X_train, y=y_train)
tsdata    = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=0)
testdata  = tsdata.flow(x=X_test, y=y_test)

# %%
checkpoint = ModelCheckpoint("ieeercnn_vgg16_1.h5",
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             save_weights_only=False,
                             mode='auto', period=1)

early = EarlyStopping(monitor='val_loss',
                      min_delta=0,
                      patience=100,
                      verbose=1,
                      mode='auto')

hist = model_final.fit_generator(generator= traindata,
                                 steps_per_epoch= 10,
                                 epochs= 100,
                                 validation_data= testdata,
                                 validation_steps=2,
                                 callbacks=[checkpoint,early])

# %%
from IPython.display import HTML
def create_download_link(title = "Download model file", filename = './RNN_model.h5'):
    html = '<a href={filename}>{title}</a>'
    html = html.format(title=title,filename=filename)
    return HTML(html)


model_final.save('./RNN_model.h5')
# create a link to download the model
create_download_link(filename='./RNN_model.h5')

# %%
img=random.choice(images)
img = cv2.imread(os.path.join(dataset_path,img))
ss.setBaseImage(img)
ss.switchToSelectiveSearchFast()
ssresults = ss.process()
imout = img.copy()
for e,result in enumerate(ssresults):
    if e < 2000:
        x,y,w,h = result
        timage = imout[y:y+h,x:x+w]
        resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
        img = np.expand_dims(resized, axis=0)
        out= model_final.predict(img)
        if out[0][0] > 0.7:
            cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
plt.figure()
plt.imshow(imout)
